# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('class_data.csv')
df.head()
# Out:
#    id  gender  instagram_followers  linkedin_con  texts_yesterday  \
# 0   1    Male                248.0         154.0              100
# 1   3  Female                427.0         400.0               60
# 2   4  Female                390.0         230.0               80
# 3   6  Female                428.0         252.0               30
# 4   7    Male                  0.0         123.0               30
#
#    phones_owned  apps_phone os_phone like_social       like_tech
# 0             8         100  Android    Disagree  Strongly agree
# 1             7          99      iOS       Agree           Agree
# 2             6          77      iOS       Agree           Agree
# 3             5          60      iOS       Agree           Agree
# 4             5          39  Android       Agree       Undecided

# %%
pd.value_counts(df.texts_yesterday)
# Out:
# 30     4
# 50     2
# 100    2
# 28     1
# 60     1
# 88     1
# 20     1
# 17     1
# 80     1
# 44     1
# 10     1
# 9      1
# 33     1
# Name: texts_yesterday, dtype: int64

# %%
pd.crosstab(df.gender, df.texts_yesterday)
# Out:
# texts_yesterday  9    10   17   20   28   30   33   44   50   60   80   88   \
# gender
# Female             1    0    0    0    1    2    1    0    2    1    1    0
# Male               0    1    1    1    0    2    0    1    0    0    0    1
#
# texts_yesterday  100
# gender
# Female             1
# Male               1

# %%
pd.crosstab(df.texts_yesterday, df.gender, normalize="columns")
# Out:
# gender           Female   Male
# texts_yesterday
# 9                   0.1  0.000
# 10                  0.0  0.125
# 17                  0.0  0.125
# 20                  0.0  0.125
# 28                  0.1  0.000
# 30                  0.2  0.250
# 33                  0.1  0.000
# 44                  0.0  0.125
# 50                  0.2  0.000
# 60                  0.1  0.000
# 80                  0.1  0.000
# 88                  0.0  0.125
# 100                 0.1  0.125

# %%
sns.countplot(x="texts_yesterday", hue="gender", data=df)
plt.show()
